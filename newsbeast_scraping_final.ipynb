# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
main_url = "https://www.newsbeast.gr/politiki/ekloges-2023/page/"

teaser_soups_list = []
start_page = 1
end_page = 10

for i in range(start_page, end_page+1):
  page_url = main_url + str(i)
  page = requests.get(page_url)
  teaser_soup = BeautifulSoup(page.text, 'html.parser')
  teaser_soups_list.append(teaser_soup)

# %%
teaser_articles_list = []
for teaser_soup in teaser_soups_list:
  teaser_articles = teaser_soup.find_all('div', {'class': 'jsx-107431441 articleDisplay'})
  for teaser_article in teaser_articles:
    teaser_article_dict = {}
    h4_a = teaser_article.find('h4').find('a')
    if h4_a:
      teaser_article_dict['Title'] = h4_a.text
      if ('https://') not in h4_a['href']:
        teaser_article_dict['Url'] = 'https://www.newsbeast.gr' + h4_a['href']
      else :
        teaser_article_dict['Url']= h4_a['href']
      lead = teaser_article.find('a')
      all=requests.get(teaser_article_dict['Url'])
      all_ar=BeautifulSoup(all.text, 'html.parser')
      whole_ar=all_ar.find('div',{'class':'jsx-2277262082'})
      if whole_ar:
        whole_ar=whole_ar.text
      teaser_article_dict['Article_content']=whole_ar
    if lead:
      teaser_article_dict['Lead'] = lead.text
    section = teaser_article.find('a', {'class': 'category'})
    if section:
      teaser_article_dict['Section'] = section.text
    datetime = teaser_article.find('time')
    if datetime:
      teaser_article_dict['Datetime'] = datetime.text
    teaser_articles_list.append(teaser_article_dict)

# %%
news_beast_teaser_articles_df = pd.DataFrame(teaser_articles_list)
news_beast_teaser_articles_df
# Out:
#                                                  Title  \
# 0    Εκλογές 2023: Την έδρα της Α’ Θεσσαλονίκης επι...
# 1    Εκλογές 2023: Κρατά την έδρα της Α’ Θεσσαλονίκ...
# 2    Γαλάζιες ανατροπές φέρνει η ολοκλήρωση της κατ...
# 3    Λάκης Λαζόπουλος για ΣΥΡΙΖΑ: Κάνει προσπάθειες...
# 4    Η επόμενη μέρα στο ΣΥΡΙΖΑ: Το μέλλον του Αλέξη...
# ..                                                 ...
# 495  Εκλογές 2023 – Μητσοτάκης: Θα φτάσουμε το μέσο...
# 496  Ανδρουλάκης: Ας τελειώσουν τους επικίνδυνους τ...
# 497  Ένταση ανάμεσα σε Σκέρτσο και Τσαπανίδου – «Εν...
# 498  Καταγγελία Φλωρίδη: Μεταφέρθηκαν χιλιάδες μουσ...
# 499  ΣΥΡΙΖΑ: Δεν υπήρξε καμία πληροφόρηση προφορική...
#
#                                                    Url  \
# 0    https://www.newsbeast.gr/politiki/arthro/98208...
# 1    https://www.newsbeast.gr/politiki/arthro/98196...
# 2    https://www.newsbeast.gr/politiki/arthro/98181...
# 3    https://www.newsbeast.gr/politiki/arthro/98124...
# 4    https://www.newsbeast.gr/politiki/arthro/98071...
# ..                                                 ...
# 495  https://www.newsbeast.gr/politiki/arthro/97593...
# 496  https://www.newsbeast.gr/politiki/arthro/97591...
# 497  https://www.newsbeast.gr/politiki/arthro/97591...
# 498  https://www.newsbeast.gr/politiki/ekloges-2023...
# 499  https://www.newsbeast.gr/politiki/arthro/97587...
#
#                                        Article_content  \
# 0    \nΣε τρεις περιφερειακές ενότητες ήταν υποψήφι...
# 1    \nΤην απόφαση να κρατήσει την έδρα της Α΄ Θεσσ...
# 2    \nΣημαντικές ανακατατάξεις και καραμπόλες φέρν...
# 3    \nΤο εκλογικό αποτέλεσμα της 25ης Ιουνίου σχολ...
# 4    \nΈχει χάσει ο ΣΥΡΙΖΑ την επαφή του με την κοι...
# ..                                                 ...
# 495  \nΤο μήνυμα ότι η Ελλάδα έχει ανάγκη από κυβέρ...
# 496  \nΟλοκληρώνοντας την επίσκεψή του στην Κρήτη ο...
# 497  \nΣτα ύψη ανέβηκε το πολιτικό θερμόμετρο για α...
# 498  \nΟ πρώην υπουργός του ΠΑΣΟΚ, Γιώργος Φλωρίδης...
# 499  \nΔιευκρινίσεις για το ζήτημα της Θράκης έδωσα...
#
#                                                   Lead  \
# 0    Εκλογές 2023: Την έδρα της Α’ Θεσσαλονίκης επι...
# 1    Εκλογές 2023: Κρατά την έδρα της Α’ Θεσσαλονίκ...
# 2    Γαλάζιες ανατροπές φέρνει η ολοκλήρωση της κατ...
# 3    Λάκης Λαζόπουλος για ΣΥΡΙΖΑ: Κάνει προσπάθειες...
# 4    Η επόμενη μέρα στο ΣΥΡΙΖΑ: Το μέλλον του Αλέξη...
# ..                                                 ...
# 495  Εκλογές 2023 – Μητσοτάκης: Θα φτάσουμε το μέσο...
# 496  Ανδρουλάκης: Ας τελειώσουν τους επικίνδυνους τ...
# 497  Ένταση ανάμεσα σε Σκέρτσο και Τσαπανίδου – «Εν...
# 498  Καταγγελία Φλωρίδη: Μεταφέρθηκαν χιλιάδες μουσ...
# 499  ΣΥΡΙΖΑ: Δεν υπήρξε καμία πληροφόρηση προφορική...
#
#                     Section          Datetime
# 0                  ΠΟΛΙΤΙΚΗ  02/07/2023 05:30
# 1                  ΠΟΛΙΤΙΚΗ  01/07/2023 09:43
# 2                  ΠΟΛΙΤΙΚΗ  30/06/2023 14:00
# 3                  ΠΟΛΙΤΙΚΗ  29/06/2023 09:04
# 4                  ΠΟΛΙΤΙΚΗ  29/06/2023 09:01
# ..                      ...               ...
# 495                ΠΟΛΙΤΙΚΗ  13/06/2023 11:01
# 496                ΠΟΛΙΤΙΚΗ  13/06/2023 10:49
# 497                ΠΟΛΙΤΙΚΗ  13/06/2023 10:45
# 498  Εκλογές 2023: Ειδήσεις  13/06/2023 09:47
# 499                ΠΟΛΙΤΙΚΗ  13/06/2023 09:19
#
# [500 rows x 6 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Δημιουργία του dataframe
news_beast_teaser_articles_df = pd.DataFrame(teaser_articles_list)
news_beast_teaser_articles_df.to_csv("drive/MyDrive/newsbeast.csv", index=False)
